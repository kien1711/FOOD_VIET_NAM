# %% [markdown]
# <a href="https://colab.research.google.com/github/kien1711/FOOD_VIET_NAM/blob/main/food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![qrcode_github.com (4).png](data:image/png;base64,...)

# %%
link data
https://drive.google.com/drive/folders/1fbkfVic01S7VU8oCGd2Wj_2Gd9beOl6w?usp=sharing

# %%
# khai báo thư viện
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam,SGD
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

from keras.models import load_model
import numpy as np
from keras.preprocessing.image import load_img,img_to_array

# %%
# khai báo một số biến và đường dẫn
trainning = '../content/drive/MyDrive/tri_tue_nhan_tao/Food/train'
test = '..//content/drive/MyDrive/tri_tue_nhan_tao/Food/test'
seed = 10
BATCH_SIZE = 16

# %%
# mở rộng thêm lượng data bằng cách dùng ImageDataGenerator
data_generator = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

val_data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

test_generator = ImageDataGenerator(rescale=1./255)

# %%
# Genera/tor data train

train_generator = data_generator.flow_from_directory(trainning, target_size=(150,150), shuffle=True, seed=seed,  # target_size: resize ảnh đầu ra
                                            class_mode='categorical', batch_size=BATCH_SIZE, subset="training")  # shuffle=True: sắp xếp dữ liệu theo chữ và số

# Generator data validation
validation_generator = val_data_generator.flow_from_directory(trainning, target_size=(150,150), shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="validation")

# Generator data test
test_generator = test_generator.flow_from_directory(test, target_size=(150,150), shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=1) #batch_size = 1 để test từng ảnh 1

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 1619 images belonging to 10 classes.
# Found 399 images belonging to 10 classes.
# Found 431 images belonging to 10 classes.
# Classes: ['banh_chung', 'banh_mi', 'banh_xeo', 'canh_kho_qua', 'com_tam', 'ga', 'goi_tron', 'pho bo', 'thit kho', 'xoi']

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    
    plt.subplot(330 + 1 + i)
    batch = train_generator.next()[0]*255
    image = batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %%
model = Sequential()
# input layer
model.add(Conv2D(32,(3,3),activation='relu', 
                 kernel_initializer='he_uniform',
                 padding = 'same', input_shape=(150,150,3))) 
# hidden layer
model.add(Conv2D(64,(3,3),activation='relu', 
                 kernel_initializer='he_uniform',
                 padding = 'same')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 

# output layer
model.add(Flatten())
model.add(Dense(128,activation='relu',
                kernel_initializer='he_uniform'))

model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 64)       0
#  )
#
#  flatten (Flatten)           (None, 360000)            0
#
#  dense (Dense)               (None, 128)               46080128
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 46,100,810
# Trainable params: 46,100,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
opt=SGD(lr=0.001, momentum=0.9)   # lr toc do hoc
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
#Training
history = model.fit(train_generator,epochs=100,
                    batch_size=64,
                    validation_data=validation_generator,
                    verbose=1)
# Out:
# Epoch 1/100
# 102/102 [==============================] - ETA: 0s - loss: 1.0270 - accuracy: 0.6578
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 102/102 [==============================] - 14s 139ms/step - loss: 1.0270 - accuracy: 0.6578 - val_loss: 0.9180 - val_accuracy: 0.7043
# Epoch 2/100
# 102/102 [==============================] - 14s 139ms/step - loss: 1.0363 - accuracy: 0.6498 - val_loss: 1.0567 - val_accuracy: 0.6717
# Epoch 3/100
# 102/102 [==============================] - 15s 143ms/step - loss: 1.0319 - accuracy: 0.6418 - val_loss: 1.0151 - val_accuracy: 0.6591
# Epoch 4/100
# 102/102 [==============================] - 14s 138ms/step - loss: 1.
100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.8656 - accuracy: 0.7048 - val_loss: 1.0059 - val_accuracy: 0.6992
# Epoch 55/100
# 102/102 [==============================] - 14s 136ms/step - loss: 0.8322 - accuracy: 0.7245 - val_loss: 0.9210 - val_accuracy: 0.7243
# Epoch 56/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.8400 - accuracy: 0.7140 - val_loss: 1.0404 - val_accuracy: 0.6942
# Epoch 57/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.8472 - accuracy: 0.7091 - val_loss: 0.9790 - val_accuracy: 0.7018
# Epoch 58/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.8695 - accuracy: 0.7048 - val_loss: 0.9173 - val_accuracy: 0.6942
# Epoch 59/100
# 102/102 [==============================] - 14s 132ms/step - loss: 0.8398 - accuracy: 0.7128 - val_loss: 0.9689 - val_accuracy: 0.6917
# Epoch 60/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.8208 - accuracy: 0.7202 - val_loss: 1.0073 - val_accuracy: 0.7093
# Epoch 61/100
# 102/102 [==============================] - 14s 132ms/step - loss: 0.7988 - accuracy: 0.7295 - val_loss: 0.9639 - val_accuracy: 0.7193
# Epoch 62/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.8131 - accuracy: 0.7103 - val_loss: 0.9738 - val_accuracy: 0.6992
# Epoch 63/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.8246 - accuracy: 0.7245 - val_loss: 0.8857 - val_accuracy: 0.7218
# Epoch 64/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.8065 - accuracy: 0.7208 - val_loss: 0.9299 - val_accuracy: 0.7243
# Epoch 65/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.8052 - accuracy: 0.7233 - val_loss: 1.0052 - val_accuracy: 0.7143
# Epoch 66/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.7761 - accuracy: 0.7369 - val_loss: 0.9930 - val_accuracy: 0.7218
# Epoch 67/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.8213 - accuracy: 0.7078 - val_loss: 0.9419 - val_accuracy: 0.7018
# Epoch 68/100
# 102/102 [==============================] - 14s 138ms/step - loss: 0.8181 - accuracy: 0.7221 - val_loss: 0.9482 - val_accuracy: 0.7143
# Epoch 69/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.7955 - accuracy: 0.7393 - val_loss: 0.8925 - val_accuracy: 0.7243
# Epoch 70/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.8107 - accuracy: 0.7276 - val_loss: 0.9493 - val_accuracy: 0.7193
# Epoch 71/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.8040 - accuracy: 0.7103 - val_loss: 1.0677 - val_accuracy: 0.6967
# Epoch 72/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.8268 - accuracy: 0.7153 - val_loss: 0.9942 - val_accuracy: 0.7093
# Epoch 73/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.7996 - accuracy: 0.7221 - val_loss: 1.0175 - val_accuracy: 0.7193
# Epoch 74/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.7761 - accuracy: 0.7344 - val_loss: 0.9627 - val_accuracy: 0.7243
# Epoch 75/100
# 102/102 [==============================] - 14s 132ms/step - loss: 0.7675 - accuracy: 0.7338 - val_loss: 1.0108 - val_accuracy: 0.7218
# Epoch 76/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7768 - accuracy: 0.7307 - val_loss: 0.9578 - val_accuracy: 0.7393
# Epoch 77/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7979 - accuracy: 0.7251 - val_loss: 0.9663 - val_accuracy: 0.7143
# Epoch 78/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.8094 - accuracy: 0.7307 - val_loss: 0.9165 - val_accuracy: 0.7243
# Epoch 79/100
# 102/102 [==============================] - 14s 136ms/step - loss: 0.8044 - accuracy: 0.7196 - val_loss: 0.9717 - val_accuracy: 0.7293
# Epoch 80/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7686 - accuracy: 0.7461 - val_loss: 0.9527 - val_accuracy: 0.7193
# Epoch 81/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7547 - accuracy: 0.7375 - val_loss: 0.8625 - val_accuracy: 0.7569
# Epoch 82/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.7426 - accuracy: 0.7548 - val_loss: 0.9114 - val_accuracy: 0.7444
# Epoch 83/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7315 - accuracy: 0.7542 - val_loss: 0.9676 - val_accuracy: 0.7243
# Epoch 84/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.7814 - accuracy: 0.7301 - val_loss: 1.0938 - val_accuracy: 0.6842
# Epoch 85/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.7452 - accuracy: 0.7468 - val_loss: 0.8952 - val_accuracy: 0.7318
# Epoch 86/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7746 - accuracy: 0.7307 - val_loss: 0.8415 - val_accuracy: 0.7393
# Epoch 87/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.7506 - accuracy: 0.7363 - val_loss: 0.9286 - val_accuracy: 0.7318
# Epoch 88/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7780 - accuracy: 0.7221 - val_loss: 1.0027 - val_accuracy: 0.7444
# Epoch 89/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7341 - accuracy: 0.7486 - val_loss: 1.0553 - val_accuracy: 0.7068
# Epoch 90/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.7861 - accuracy: 0.7338 - val_loss: 0.9976 - val_accuracy: 0.7293
# Epoch 91/100
# 102/102 [==============================] - 14s 139ms/step - loss: 0.8103 - accuracy: 0.7344 - val_loss: 0.8739 - val_accuracy: 0.7419
# Epoch 92/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7244 - accuracy: 0.7610 - val_loss: 0.8935 - val_accuracy: 0.7419
# Epoch 93/100
# 102/102 [==============================] - 14s 135ms/step - loss: 0.6904 - accuracy: 0.7523 - val_loss: 0.9012 - val_accuracy: 0.7293
# Epoch 94/100
# 102/102 [==============================] - 14s 132ms/step - loss: 0.7599 - accuracy: 0.7474 - val_loss: 0.8608 - val_accuracy: 0.7519
# Epoch 95/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7344 - accuracy: 0.7523 - val_loss: 0.9331 - val_accuracy: 0.7494
# Epoch 96/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7762 - accuracy: 0.7369 - val_loss: 0.9060 - val_accuracy: 0.7343
# Epoch 97/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7996 - accuracy: 0.7418 - val_loss: 1.0041 - val_accuracy: 0.7193
# Epoch 98/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.7162 - accuracy: 0.7449 - val_loss: 0.8665 - val_accuracy: 0.7343
# Epoch 99/100
# 102/102 [==============================] - 14s 133ms/step - loss: 0.7392 - accuracy: 0.7437 - val_loss: 0.9000 - val_accuracy: 0.7343
# Epoch 100/100
# 102/102 [==============================] - 14s 134ms/step - loss: 0.7081 - accuracy: 0.7573 - val_loss: 0.9976 - val_accuracy: 0.7143

# %%
model.save('/content/drive/MyDrive/tri_tue_nhan_tao/Food/food.h')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/tri_tue_nhan_tao/Food/food.h/assets

# %%
model_food = tf.keras.models.load_model('/content/drive/MyDrive/tri_tue_nhan_tao/Food/food.h')

# %%
img=load_img('/content/drive/MyDrive/tri_tue_nhan_tao/Food/pred/thitkho1.jpg',target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img.astype('float32')
img/=255
np.argmax(model_food.predict(img),axis=1)[0]
classes[np.argmax(model_food.predict(img),axis=1)[0]]
# Out:
# 'thit kho'

# %%
img=load_img('/content/drive/MyDrive/tri_tue_nhan_tao/Food/pred/comtam4.jpg',target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img.astype('float32')
img/=255
np.argmax(model_food.predict(img),axis=1)[0]
classes[np.argmax(model_food.predict(img),axis=1)[0]]
# Out:
# 'com_tam'

# %%
img=load_img('/content/drive/MyDrive/tri_tue_nhan_tao/Food/pred/goitron2.jpg',target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img.astype('float32')
img/=255
np.argmax(model_food.predict(img),axis=1)[0]
classes[np.argmax(model_food.predict(img),axis=1)[0]]
# Out:
# 'banh_xeo'

# %%
img=load_img('/content/drive/MyDrive/tri_tue_nhan_tao/Food/pred/xoi3.jpg',target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img.astype('float32')
img/=255
np.argmax(model_food.predict(img),axis=1)[0]
classes[np.argmax(model_food.predict(img),axis=1)[0]]
# Out:
# 'xoi'

# %%
img=load_img('/content/drive/MyDrive/tri_tue_nhan_tao/Food/pred/comtam3.jpg',target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img.astype('float32')
img/=255
np.argmax(model_food.predict(img),axis=1)[0]
classes[np.argmax(model_food.predict(img),axis=1)[0]]
# Out:
# 'pho bo'
